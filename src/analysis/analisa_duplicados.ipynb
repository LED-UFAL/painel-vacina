# %%
from sqlalchemy import create_engine
import os
from datetime import datetime
import pandas as pd
import numpy as np

# %%
connection_uri = 'postgres://luizcelso:p171@192.168.15.4:5432/vacinas'
engine = create_engine(connection_uri)

# %%
sql = """
SELECT * FROM vacinacao
WHERE paciente_id IN (SELECT paciente_id FROM duplicados)
ORDER BY paciente_id;
"""

df = pd.read_sql(sql, engine)

df
# Out:
#                                                paciente_id  paciente_idade  \
# 0        000012b859a40586854a354e0c15de1886c8c1b2fa2cd7...              82
# 1        000012b859a40586854a354e0c15de1886c8c1b2fa2cd7...              82
# 2        000012b859a40586854a354e0c15de1886c8c1b2fa2cd7...              82
# 3        00004fd164930b491aa1a042c4ede6818e2c7d3c725ef9...              86
# 4        00004fd164930b491aa1a042c4ede6818e2c7d3c725ef9...              86
# ...                                                    ...             ...
# 1609728  ffff62d3a6b126d61015aa367793dce4d99a6af9d9e9aa...              43
# 1609729  ffff7b6e3a0c4c5bbea83d93de6129267c1cc23eb3f1a7...              78
# 1609730  ffff7b6e3a0c4c5bbea83d93de6129267c1cc23eb3f1a7...              78
# 1609731  ffff7b6e3a0c4c5bbea83d93de6129267c1cc23eb3f1a7...              78
# 1609732  ffff7b6e3a0c4c5bbea83d93de6129267c1cc23eb3f1a7...              78
#
#         paciente_dataNascimento paciente_enumSexoBiologico  \
# ...

# %%
df['paciente_id'].value_counts().sort_values(ascending=False).head(10)
# Out:
# 6c62b4b30f72b5dea26d914c5ede09ec6d75e4bbe8f01bac4242a7cdc10f14c3    114137
# e11386adac51e696fab391770867932f5a82bd3efaa46d20f86bd2c2b8d7a7e9        61
# b1bc8e3955be2358d86afbbd56e334a3ab189c631ada7064c7b4ca5eaf51d10c         8
# 8a4ebd3a8fb193b7055655bd8acd7f9f9590f0cca64093fbb8168cf9719baadf         8
# 544a1a1b3010a3dead231159c2c7f759b612af7051f44a83617963af57ca9607         8
# b9846c30f1c0e48cbbff68629863785f29af1c92b4998e2d2243fe69acc4cc8e         8
# d0c6991e49a192cc5bdf18c6247d5e48ca0e6de910a2c49624f2eb11031fa2c4         8
# 466a09343431d9fac4f9673f6be1cd06cba95feccac1f8a5a63aa3bdf88f4c55         8
# 88c3864ab71a98fc1378e4f87b9863e93d375b2cbc5bc2f302dca51649cd677c         8
# c00d36c66612b474e0209b7afd550af642e97147a2ee2d4faad9d7d4dfd20abf         8
# Name: paciente_id, dtype: int64

# %%
df['paciente_id'].value_counts().sum()
# Out:
# 1609733

# %%
# sql = """
# SELECT paciente_id FROM vacinacao;
# """

# df2 = pd.read_sql(sql, engine)

# df2
# Out:
#                                                 paciente_id
# 0         7f6a31e336db46cbff7a5ead09849e44217274d3441863...
# 1         b3fa7cd0a3131948ff66cc1bd0697becbdd5b329de264b...
# 2         c8d1fd8296a811cdbbf1aca5e0568e402bcd71c0c4020a...
# 3         b4b6e52ec7a2463bfeaefbdd027952dcfd1008c6140755...
# 4         8bc5311506583aa516ea01d59adeecae81207422c776d9...
# ...                                                     ...
# 42993906  c60101353efa514562222b9f41aba5647e67babf1cf195...
# 42993907  cb4a2cd5227f1435856358d614b0810eaf9e6e06c2d9b3...
# 42993908  5496287f55006d7cdd6c6c14f5a369440da15a086c7cdb...
# 42993909  da8481d50b56013d494d30f49cfbccb4bfb77e4c4ff0ac...
# 42993910  732bb6c0d27b40cdeafbf3315d69fd3f74fd4f474255f0...
#
# [42993911 rows x 1 columns]

# %%
# df2['paciente_id'].value_counts().sort_values(ascending=False).head(10)
# Out:
# 6c62b4b30f72b5dea26d914c5ede09ec6d75e4bbe8f01bac4242a7cdc10f14c3    114137
# e11386adac51e696fab391770867932f5a82bd3efaa46d20f86bd2c2b8d7a7e9        61
# 544a1a1b3010a3dead231159c2c7f759b612af7051f44a83617963af57ca9607         8
# 466a09343431d9fac4f9673f6be1cd06cba95feccac1f8a5a63aa3bdf88f4c55         8
# b1bc8e3955be2358d86afbbd56e334a3ab189c631ada7064c7b4ca5eaf51d10c         8
# b9846c30f1c0e48cbbff68629863785f29af1c92b4998e2d2243fe69acc4cc8e         8
# 88c3864ab71a98fc1378e4f87b9863e93d375b2cbc5bc2f302dca51649cd677c         8
# 8a4ebd3a8fb193b7055655bd8acd7f9f9590f0cca64093fbb8168cf9719baadf         8
# d0c6991e49a192cc5bdf18c6247d5e48ca0e6de910a2c49624f2eb11031fa2c4         8
# c00d36c66612b474e0209b7afd550af642e97147a2ee2d4faad9d7d4dfd20abf         8
# Name: paciente_id, dtype: int64
